# %% [markdown]
# # Estadisticas datos: Proceso uso de una sala (todo 2016)

# %%
import pandas as pd
usoDeSala = pd.read_csv('../data/datosProcesados/usoDeUnaSala.txt')

# %%
usoDeSala.describe().tail(7)
# Out:
#       numEquipos  PorcentajeOcupacion        dia        mes     año  \
# mean   38.666667             0.107251  15.894655   6.950850  2016.0
# std     6.944234             0.170760   8.911887   3.215985     0.0
# min    30.000000             0.000000   1.000000   1.000000  2016.0
# 25%    30.000000             0.000000   8.000000   4.000000  2016.0
# 50%    39.000000             0.025641  16.000000   7.000000  2016.0
# 75%    47.000000             0.133333  24.000000  10.000000  2016.0
# max    47.000000             1.166667  31.000000  12.000000  2016.0
#
#            hora     minuto     semana
# mean  11.499514  27.502737   7.170206
# std    6.923860  17.260465   6.606164
# min    0.000000   0.000000  -1.000000
# 25%    6.000000  15.000000  -1.000000
# 50%   11.000000  30.000000   7.000000
# 75%   18.000000  45.000000  13.000000
# max   23.000000  59.000000  20.000000

# %% [markdown]
# # Estadisticas datos: Proceso uso de una sala (solo periodos semestrales)

# %%
import pandas as pd
usoDeSala = pd.read_csv('../data/datosProcesados/usoDeUnaSala.txt')

# %%
usoDeSala[usoDeSala.semana != -1].describe().tail(7)
# Out:
#       numEquipos  PorcentajeOcupacion        dia        mes     año  \
# mean   38.666667             0.131830  15.923428   6.427152  2016.0
# std     6.944238             0.181991   8.880718   3.238352     0.0
# min    30.000000             0.000000   1.000000   1.000000  2016.0
# 25%    30.000000             0.000000   8.000000   3.000000  2016.0
# 50%    39.000000             0.042553  16.000000   5.000000  2016.0
# 75%    47.000000             0.230769  24.000000   9.000000  2016.0
# max    47.000000             1.166667  31.000000  11.000000  2016.0
#
#            hora     minuto     semana
# mean  11.504117  27.500632  10.114429
# std    6.924165  17.260493   5.161842
# min    0.000000   0.000000   1.000000
# 25%    6.000000  15.000000   6.000000
# 50%   12.000000  30.000000  10.000000
# 75%   18.000000  45.000000  15.000000
# max   23.000000  55.000000  20.000000

# %% [markdown]
# # Estadisticas datos: Proceso uso de una sala (solo waira 1)

# %%
import pandas as pd
usoDeSala = pd.read_csv('../data/datosProcesados/usoDeUnaSala.txt')

# %%
usoDeSala[(usoDeSala.semana != -1) & (usoDeSala.sala == 'waira 1')].describe().tail(7)
# Out:
#       numEquipos  PorcentajeOcupacion        dia        mes     año  \
# mean        47.0             0.120176  15.923428   6.427152  2016.0
# std          0.0             0.162687   8.880759   3.238367     0.0
# min         47.0             0.000000   1.000000   1.000000  2016.0
# 25%         47.0             0.000000   8.000000   3.000000  2016.0
# 50%         47.0             0.021277  16.000000   5.000000  2016.0
# 75%         47.0             0.212766  24.000000   9.000000  2016.0
# max         47.0             1.000000  31.000000  11.000000  2016.0
#
#            hora     minuto     semana
# mean  11.504117  27.500632  10.114429
# std    6.924197  17.260574   5.161866
# min    0.000000   0.000000   1.000000
# 25%    6.000000  15.000000   6.000000
# 50%   12.000000  30.000000  10.000000
# 75%   18.000000  45.000000  15.000000
# max   23.000000  55.000000  20.000000

# %% [markdown]
# # pruebas

# %%
usoSalaSemestres7a9 = usoDeSala[(usoDeSala.hora < 19) & (usoDeSala.hora > 7) & (usoDeSala.semana != -1) ]
usoSalaSemestres7a9.to_csv('../data/datosProcesados/usoDeSalaSoloSemestres7a9.txt', encoding='utf-8')
usoSalaSemestres7a9
# Out:
#            sala  numEquipos  PorcentajeOcupacion  dia  mes   año  hora  \
# 369      turing          39             0.051282   28    1  2016     8
# 370     waira 1          47             0.021277   28    1  2016     8
# 371     waira 2          30             0.000000   28    1  2016     8
# 372      turing          39             0.051282   28    1  2016     8
# 373     waira 1          47             0.021277   28    1  2016     8
# 374     waira 2          30             0.000000   28    1  2016     8
# 375      turing          39             0.051282   28    1  2016     8
# 376     waira 1          47             0.021277   28    1  2016     8
# 377     waira 2          30             0.000000   28    1  2016     8
# 378      turing          39             0.051282   28    1  2016     8
# 379     waira 1          47             0.021277   28    1  2016     8
# 380     waira 2          30             0.000000   28    1  2016     8
# ...
